# %%
import requests
import xml.etree.ElementTree as ET
from urllib.parse import quote_plus

def parse_pom_dependencies_from_string(pom_content):
    # Parse the pom.xml content
    root = ET.fromstring(pom_content)

    # Define the namespace map to handle the default namespace used in pom.xml
    namespaces = {'m': 'http://maven.apache.org/POM/4.0.0'}

    # Get the properties from the pom.xml content
    properties = root.find('m:properties', namespaces)
    properties_dict = {}
    if properties is not None:
        for child in properties:
            tag = child.tag.replace('{' + namespaces['m'] + '}', '')  # Strip namespace
            properties_dict[tag] = child.text

    # Find all the dependency elements in the pom.xml content
    dependencies = root.findall(".//m:dependencies/m:dependency", namespaces)

    # Extract the groupId, artifactId, and version for each dependency
    dependency_list = []
    for dependency in dependencies:
        groupId = dependency.find('m:groupId', namespaces).text
        artifactId = dependency.find('m:artifactId', namespaces).text
        version_element = dependency.find('m:version', namespaces)
        if version_element is not None:
            # Resolve the version from properties if necessary
            version_text = version_element.text
            if version_text.startswith('${') and version_text.endswith('}'):
                property_name = version_text[2:-1]
                version = properties_dict.get(property_name, 'VERSION PROPERTY NOT FOUND')
            else:
                version = version_text
        else:
            version = 'VERSION NOT SPECIFIED'
        dependency_list.append(f"{groupId}:{artifactId}:{version}")

    return dependency_list

# Your credentials and endpoint


# The search query
SEARCH_QUERY = "pom.xml"
# Initialize variables
files = []

# Properly encode the search query to be used in a URL
encoded_query = quote_plus(SEARCH_QUERY)
next_page = f"{BASE_URL}/{WORKSPACE}/search/code?search_query={encoded_query}"

# Loop through all pages of search results
while next_page:
    response = requests.get(next_page, auth=(USERNAME, PASSWORD))

    # Check if the request was successful
    if response.status_code == 200:
        search_results = response.json()
        for result in search_results['values']:
            path = result['file']['links']['self']['href']
            libraries = []
            # only check if file is a pom.xml
            if SEARCH_QUERY in result['file']['path']:
                libraries = parse_pom_dependencies_from_string(requests.get(path, auth=(USERNAME, PASSWORD)).text)

            file = {
                'name': result['file']['path'],
                'path': path,
                'content': libraries
            }
            files.append(file)

        # Get the next page URL, if it exists
        next_page = search_results.get('next', None)
    else:
        print("Failed to search the repository:", response.status_code, response.text)
        next_page = None  # Stop if there's an error

print(len(files))
# Out:
# 192

# %%
for file in files:
    print('--------------------------------------------------------------------------------------------')
    print('File Name = ' + file['name'])
    print('File Path = ' + file['path'])
    print('--------------------------------------------------------------------------------------------')
    for library in file['content']:
        print(library)
    print('')
# Out:
# --------------------------------------------------------------------------------------------
# File Name = app/the-mummy-aws/pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/themummy/src/57040a7e23ee53e1fcc930c82e8230e7126176ed/app/the-mummy-aws/pom.xml
# --------------------------------------------------------------------------------------------
# junit:junit:VERSION NOT SPECIFIED
# com.amazonaws:aws-java-sdk-sqs:1.11.490
# com.google.code.gson:gson:2.8.5
# org.apache.commons:commons-lang3:3.0
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kafka-connect-simple-key/src/ed811a405628414fcb4001787e9482d30b67c28d/pom.xml
# --------------------------------------------------------------------------------------------
# org.apache.kafka:connect-api:1.1.0
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/communication-events/src/598f331d4b6767227472f58e81ffbc7c328a4349/pom.xml
# --------------------------------------------------------------------------------------------
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.apache.logging.log4j:log4j-slf4j-impl:2.12.0
# junit:junit:4.13.2
# com.article:identity-cli:0.2
# org.apache.kafka:kafka-clients:2.7.0
# org.apache.avro:avro:1.8.2
# org.apache.camel:camel-spring-boot-starter:3.0.0-M2
# org.apache.camel:camel-avro-starter:3.0.0-M2
# org.apache.camel:camel-kafka-starter:3.0.0-M2
# org.apache.camel:camel-jackson-starter:3.0.0-M2
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# org.projectlombok:lombok:1.18.20
# io.confluent:kafka-avro-serializer:5.2.3
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/alchemist/src/7ac2dc38ded8639ccd86cacb222e995fb7ba85fc/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.data:spring-data-redis:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# com.google.protobuf:protobuf-java-util:3.21.3
# com.google.guava:guava:31.0.1-jre
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# com.fasterxml.jackson.core:jackson-databind:VERSION NOT SPECIFIED
# com.fasterxml.jackson.datatype:jackson-datatype-jsr310:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.kinesis:amazon-kinesis-client:2.3.6
# com.jayway.jsonpath:json-path:2.5.0
# io.lettuce:lettuce-core:VERSION NOT SPECIFIED
# com.article.platform:logging:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:grpc-spring-boot-starter:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/chronicler/src/cb5364075237557170c97415e8a06abc4de1593c/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# org.springframework.boot:spring-boot-starter-web:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# com.amazonaws:amazon-kinesis-producer:0.14.10
# javax.xml.bind:jaxb-api:2.3.1
# com.article.platform:logging:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-cache-manager/src/94fb37f6fc66ca2b79cf08eafaa3cb0fc539791a/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.13.76
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-aop:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-rest:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-security:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-validation:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-log4j2:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-actuator:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-webflux:VERSION NOT SPECIFIED
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:5.7.3
# io.sentry:sentry-log4j2:5.7.3
# org.slf4j:slf4j-api:1.7.36
# org.apache.logging.log4j:log4j-api:2.17.2
# org.apache.logging.log4j:log4j-core:2.17.2
# org.apache.logging.log4j:log4j-slf4j-impl:2.17.2
# org.apache.logging.log4j:log4j-jcl:2.17.2
# org.apache.commons:commons-lang3:VERSION NOT SPECIFIED
# org.apache.httpcomponents:httpclient:VERSION NOT SPECIFIED
# org.atteo.classindex:classindex:3.11
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.springframework.security:spring-security-test:VERSION NOT SPECIFIED
# com.flipkart.zjsonpatch:zjsonpatch:0.4.12
# io.swagger:swagger-core:1.6.6
# com.fasterxml.jackson.core:jackson-databind:2.13.2.2
# com.article:identity-cli:0.3
# org.apache.avro:avro:1.8.1
# io.confluent:kafka-avro-serializer:5.2.2
# org.springframework.kafka:spring-kafka-test:VERSION NOT SPECIFIED
# junit:junit:4.13.2
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.awssdk:sts:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatch:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchevents:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchlogs:VERSION NOT SPECIFIED
# software.amazon.awssdk:s3:VERSION NOT SPECIFIED
# commons-io:commons-io:2.11.0
# com.google.code.gson:gson:2.8.9
# io.micrometer:micrometer-core:VERSION NOT SPECIFIED
# io.micrometer:micrometer-registry-cloudwatch2:1.8.5
# org.springdoc:springdoc-openapi-ui:1.6.7
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# org.ow2.asm:asm:6.2
# org.apache.maven.surefire:surefire-junit47:3.0.0-M6
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/mock-data-injector/src/e2c3eacc30e9ae7e337e8ffaadc66b03d083abe4/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.2.7
# org.apache.kafka:kafka-clients:7.2.1-ccs
# com.article.platform:bom:1.2.7
# com.article:protobuf:1.15.81
# io.confluent:kafka-protobuf-serializer:7.2.1
# com.fasterxml.jackson.core:jackson-core:2.14.0
# org.projectlombok:lombok:1.18.24
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/odysseus/src/b61aa36cdadcd90924dfdaee9ce2168055800a5d/pom.xml
# --------------------------------------------------------------------------------------------
# org.springframework.boot:spring-boot-starter-thymeleaf:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-web:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-devtools:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.springframework.plugin:spring-plugin-core:2.0.0.RELEASE
# org.hibernate.javax.persistence:hibernate-jpa-2.1-api:1.0.0.Final
# org.springframework.data:spring-data-commons:2.3.2.RELEASE
# com.article:identity-cli:1.0
# com.atlassian.jira:jira-rest-java-client-core:5.2.2
# com.atlassian.jira:jira-rest-java-client-api:5.2.0
# com.atlassian.jira:jira-rest-java-client-app:5.2.0
# com.atlassian.fugue:fugue:2.6.1
# joda-time:joda-time:2.10.5
# org.hibernate:hibernate-validator:5.4.1.Final
# org.apache.commons:commons-text:1.8
# org.awaitility:awaitility:3.1.2
# com.vdurmont:emoji-java:4.0.0
# org.springframework.security.oauth.boot:spring-security-oauth2-autoconfigure: ${project.parent.version}
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/arch.common/src/56ee79731c53c7660f86e7f94c9440c7e3c7c600/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awscdk:aws-cdk-lib:2.81.0
# software.constructs:constructs:[10.0.0,11.0.0)
# org.projectlombok:lombok:1.18.24
# org.junit.jupiter:junit-jupiter:5.7.1
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-service/src/7ff0ff63b7912efc46de0dca79dbc72e350f2eab/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.13.76
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-aop:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-rest:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-security:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-validation:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-log4j2:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-actuator:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-webflux:VERSION NOT SPECIFIED
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:3.2.0
# io.sentry:sentry-log4j2:3.2.0
# org.slf4j:slf4j-api:1.7.26
# org.apache.logging.log4j:log4j-api:2.17.0
# org.apache.logging.log4j:log4j-core:2.17.0
# org.apache.logging.log4j:log4j-slf4j-impl:2.17.0
# org.apache.logging.log4j:log4j-jcl:2.17.0
# org.apache.commons:commons-lang3:3.8.1
# org.apache.httpcomponents:httpclient:4.5.9
# org.atteo.classindex:classindex:3.6
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.springframework.security:spring-security-test:VERSION NOT SPECIFIED
# com.flipkart.zjsonpatch:zjsonpatch:0.4.8
# io.swagger:swagger-core:1.5.22
# org.hibernate:hibernate-core:5.4.28.Final
# org.hibernate:hibernate-ehcache:5.4.28.Final
# com.fasterxml.jackson.core:jackson-databind:2.11.4
# com.opencsv:opencsv:4.5
# com.article:identity-cli:1.4
# org.apache.avro:avro:1.8.2
# io.confluent:kafka-avro-serializer:5.2.2
# org.springframework.kafka:spring-kafka-test:VERSION NOT SPECIFIED
# junit:junit:4.13.2
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# org.flywaydb:flyway-core:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.awssdk:sts:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatch:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchevents:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchlogs:VERSION NOT SPECIFIED
# software.amazon.awssdk:s3:VERSION NOT SPECIFIED
# commons-io:commons-io:2.8.0
# com.google.code.gson:gson:2.8.5
# io.micrometer:micrometer-core:VERSION NOT SPECIFIED
# io.micrometer:micrometer-registry-cloudwatch2:1.5.11
# org.springdoc:springdoc-openapi-ui:1.5.9
# com.tngtech.archunit:archunit-junit4:0.23.1
# org.ow2.asm:asm:6.2
# org.apache.maven.surefire:surefire-junit47:3.0.0-M6
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-chatbot/src/0ab026b701017d3cc350f8f33d6cd7a60c442127/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.17.46
# com.article:identity-cli:1.4
# com.harium.suneidesis.sunbot:slack:1.6.7
# org.apache.httpcomponents:httpclient:4.5.13
# com.harium:dotenv:1.0.5
# com.fasterxml.jackson.core:jackson-databind:2.10.3
# org.jsoup:jsoup:1.13.1
# junit:junit:4.12
# org.mockito:mockito-all:1.10.19
# software.amazon.awssdk:secretsmanager:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/abacus/src/f1bb9778506071abf2ea34eb0a858508af1d3cf5/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# com.google.protobuf:protobuf-java:3.21.7
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# com.article:protobuf:1.16.104
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# com.google.protobuf:protobuf-java-util:3.21.7
# com.google.guava:guava:31.0.1-jre
# com.squareup.okhttp3:okhttp:4.9.3
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.optaplanner:optaplanner-core:7.34.0.Final
# com.fasterxml.jackson.datatype:jackson-datatype-jsr310:2.13.1
# io.lettuce:lettuce-core:6.2.1.RELEASE
# com.article.platform:logging:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:grpc-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:sdk-event-consumer:VERSION NOT SPECIFIED
# io.github.resilience4j:resilience4j-spring-boot2:1.7.1
# org.springframework.boot:spring-boot-starter-aop:2.7.1
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/treasury/src/04522386ac3a02d84cc297a4537517e9e0984c34/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# com.google.protobuf:protobuf-java:3.21.7
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# javax.xml.bind:jaxb-api:2.3.1
# org.springframework.data:spring-data-redis:VERSION NOT SPECIFIED
# io.lettuce:lettuce-core:VERSION NOT SPECIFIED
# com.article.platform:logging:VERSION NOT SPECIFIED
# com.article.platform:sdk-event-consumer:VERSION NOT SPECIFIED
# com.article:protobuf:1.16.104
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# net.avalara.avatax:avatax-rest-v2-api-java_2.11:19.7.0
# com.taxjar:taxjar-java:5.0.1
# org.apache.commons:commons-collections4:4.4
# com.fasterxml.jackson.core:jackson-databind:2.13.4.2
# io.github.resilience4j:resilience4j-spring-boot2:1.7.1
# org.springframework.boot:spring-boot-starter-aop:2.7.1
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.apache.commons:commons-text:1.9
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
# com.stripe:stripe-java:20.96.0
# jakarta.xml.bind:jakarta.xml.bind-api:4.0.0-RC3
# io.confluent:kafka-avro-serializer:7.2.1
# com.paypal.sdk:rest-api-sdk:1.9.3
# com.github.tomakehurst:wiremock-jre8:2.33.2
# com.article.platform:grpc-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:secrets:VERSION NOT SPECIFIED
# it.ozimov:embedded-redis:0.7.3
# org.testcontainers:junit-jupiter:1.19.0
# org.testcontainers:testcontainers:1.19.0
# org.testcontainers:mysql:1.19.0
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-graph/src/4343c91e14d18e399894e2121c5c31472484cae5/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.45
# org.springframework.boot:spring-boot-starter-graphql:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-webflux:VERSION NOT SPECIFIED
# com.article.platform:sdk-event-consumer:VERSION NOT SPECIFIED
# com.article.platform:sdk-service:VERSION NOT SPECIFIED
# com.article.platform:secrets:VERSION NOT SPECIFIED
# com.article:protobuf:1.16.104
# com.auth0:java-jwt:4.4.0
# com.auth0:jwks-rsa:0.22.0
# com.squareup.okhttp3:okhttp:VERSION NOT SPECIFIED
# org.mapstruct:mapstruct:1.5.5.Final
# org.projectlombok:lombok:1.18.24
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# io.projectreactor:reactor-test:VERSION NOT SPECIFIED
# org.springframework.graphql:spring-graphql-test:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/memento/src/63b2fc137a3b1344b2743d6b2ebdcd9b581cff55/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.17.14
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb:VERSION NOT SPECIFIED
# software.amazon.awssdk:sso:2.17.14
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/csx-cf-templates/src/bd975ad56a3499dd634814140c754e65121fcabe/pom.xml
# --------------------------------------------------------------------------------------------
# com.fasterxml.jackson.dataformat:jackson-dataformat-yaml:2.11.2
# com.google.guava:guava:31.1-jre
# software.amazon.awscdk:aws-cdk-lib:[2.0.0,)
# software.constructs:constructs:[10.0.0,)
# org.junit.jupiter:junit-jupiter-engine:5.0.0
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/spring-kafka-streams-store/src/d0074e6d4ea5b24fd40adae3e9cd37032fd36319/pom.xml
# --------------------------------------------------------------------------------------------
# org.apache.avro:avro:1.8.2
# io.confluent:kafka-streams-avro-serde:5.3.2
# io.confluent:kafka-schema-registry-client:5.3.2
# org.springframework.cloud:spring-cloud-stream-binder-kafka-streams:3.0.0.RELEASE
# org.springframework.boot:spring-boot-starter-actuator:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-web:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/knowhere/src/a5300dab1a9887a0e935594fe4a248ec70d43420/pom.xml
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-schedule-reports/src/2ac65d913dbbaf00b558e4012e9776a25ea8fcdf/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.13.76
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-aop:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-rest:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-log4j2:VERSION NOT SPECIFIED
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:3.2.0
# io.sentry:sentry-log4j2:3.2.0
# org.slf4j:slf4j-api:VERSION NOT SPECIFIED
# org.apache.logging.log4j:log4j-api:VERSION NOT SPECIFIED
# org.apache.logging.log4j:log4j-core:VERSION NOT SPECIFIED
# org.apache.logging.log4j:log4j-slf4j-impl:VERSION NOT SPECIFIED
# org.apache.logging.log4j:log4j-jcl:VERSION NOT SPECIFIED
# org.apache.commons:commons-lang3:VERSION NOT SPECIFIED
# org.apache.httpcomponents:httpclient:VERSION NOT SPECIFIED
# org.atteo.classindex:classindex:3.6
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# com.flipkart.zjsonpatch:zjsonpatch:0.4.8
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# org.flywaydb:flyway-core:VERSION NOT SPECIFIED
# org.hibernate:hibernate-core:VERSION NOT SPECIFIED
# org.hibernate:hibernate-ehcache:VERSION NOT SPECIFIED
# com.fasterxml.jackson.datatype:jackson-datatype-jsr310:VERSION NOT SPECIFIED
# org.apache.commons:commons-csv:1.8
# org.apache.avro:avro:1.8.2
# io.confluent:kafka-avro-serializer:5.2.2
# org.springframework.kafka:spring-kafka-test:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatch:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchevents:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchlogs:VERSION NOT SPECIFIED
# software.amazon.awssdk:s3:VERSION NOT SPECIFIED
# commons-io:commons-io:2.8.0
# com.google.code.gson:gson:VERSION NOT SPECIFIED
# io.micrometer:micrometer-core:VERSION NOT SPECIFIED
# com.h2database:h2:VERSION NOT SPECIFIED
# org.ow2.asm:asm:6.2
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken/src/c56f49a124c5244356dc726b36e6690b1d4845e2/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.20.104
# io.sentry:sentry-bom:6.13.1
# io.opentelemetry:opentelemetry-bom:1.26.0
# junit:junit:4.13.2
# org.junit.jupiter:junit-jupiter-api:5.10.0
# com.tngtech.archunit:archunit:1.1.0
# com.tngtech.archunit:archunit-junit4:1.1.0
# com.tngtech.archunit:archunit-junit5:1.1.0
# org.junit.jupiter:junit-jupiter:5.10.0
# org.mockito:mockito-core:5.1.1
# org.mockito:mockito-junit-jupiter:5.1.1
# org.testcontainers:kafka:1.18.3
# org.testcontainers:mysql:1.18.3
# com.mysql:mysql-connector-j:8.1.0
# org.projectlombok:lombok:1.18.26
# org.springframework.boot:spring-boot-starter:2.7.12
# org.springframework.boot:spring-boot-starter-test:2.7.12
# org.springframework.boot:spring-boot-starter-logging:2.7.12
# org.springframework.boot:spring-boot-configuration-processor:2.7.12
# org.springframework.boot:spring-boot-starter-jdbc:2.7.12
# com.fasterxml.jackson.core:jackson-databind:2.14.2
# com.squareup.okhttp3:okhttp:4.10.0
# software.constructs:constructs:VERSION PROPERTY NOT FOUND
# software.amazon.awscdk:aws-cdk-lib:VERSION PROPERTY NOT FOUND
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/hackathon-2021-project-true-sentiment/src/a01b050862b601048f48e05b847fbcb15cd8cc5a/pom.xml
# --------------------------------------------------------------------------------------------
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-devtools:VERSION NOT SPECIFIED
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# com.github.igor-suhorukov:instagramscraper:2.2
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-dog/src/9ded1cc0a7971656c0eb4a4e067091d7e71832fc/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.13.76
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-aop:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-rest:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-security:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-validation:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-log4j2:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-webflux:VERSION NOT SPECIFIED
# org.projectlombok:lombok:1.18.20
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:3.2.0
# io.sentry:sentry-log4j2:3.2.0
# org.slf4j:slf4j-api:1.7.26
# org.apache.logging.log4j:log4j-api:2.12.0
# org.apache.logging.log4j:log4j-core:2.12.0
# org.apache.logging.log4j:log4j-slf4j-impl:2.12.0
# org.apache.logging.log4j:log4j-jcl:2.12.0
# org.apache.commons:commons-lang3:3.8.1
# org.apache.httpcomponents:httpclient:4.5.9
# org.atteo.classindex:classindex:3.6
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.springframework.security:spring-security-test:VERSION NOT SPECIFIED
# com.flipkart.zjsonpatch:zjsonpatch:0.4.8
# io.swagger:swagger-core:1.5.22
# org.hibernate:hibernate-core:5.4.28.Final
# org.hibernate:hibernate-ehcache:5.4.28.Final
# com.fasterxml.jackson.core:jackson-databind:2.11.4
# com.opencsv:opencsv:4.5
# com.article:identity-cli:0.2
# org.apache.avro:avro:1.8.2
# io.confluent:kafka-avro-serializer:5.2.2
# org.springframework.kafka:spring-kafka-test:VERSION NOT SPECIFIED
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# org.flywaydb:flyway-core:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.awssdk:sts:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatch:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchevents:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchlogs:VERSION NOT SPECIFIED
# software.amazon.awssdk:s3:VERSION NOT SPECIFIED
# commons-io:commons-io:2.8.0
# com.google.code.gson:gson:2.8.5
# io.micrometer:micrometer-core:VERSION NOT SPECIFIED
# io.micrometer:micrometer-registry-cloudwatch2:1.5.11
# org.springdoc:springdoc-openapi-ui:1.5.9
# junit:junit:4.12
# com.h2database:h2:VERSION NOT SPECIFIED
# org.ow2.asm:asm:6.2
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/ecomm-common-cdk/src/b9027883c1dee5d42b334f0eeaff278a2043302f/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awscdk:aws-cdk-lib:2.81.0
# software.constructs:constructs:[10.0.0,11.0.0)
# org.projectlombok:lombok:1.18.24
# org.junit.jupiter:junit-jupiter:5.7.1
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/customer/src/dcd6269ba9b10b7b8c4881e4b4aa211360c0f116/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-mail:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# com.google.protobuf:protobuf-java:3.21.7
# org.awaitility:awaitility:4.1.1
# com.article:protobuf:1.16.104
# com.google.protobuf:protobuf-java-util:3.21.7
# net.javacrumbs.shedlock:shedlock-spring:4.30.0
# com.google.guava:guava:31.0.1-jre
# net.javacrumbs.shedlock:shedlock-provider-dynamodb2:4.30.0
# org.apache.httpcomponents:fluent-hc:VERSION NOT SPECIFIED
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# com.fasterxml.jackson.core:jackson-databind:VERSION NOT SPECIFIED
# com.fasterxml.jackson.datatype:jackson-datatype-jsr310:VERSION NOT SPECIFIED
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.awssdk:personalizeruntime:VERSION NOT SPECIFIED
# software.amazon.awssdk:lambda:VERSION NOT SPECIFIED
# software.amazon.awssdk:sso:VERSION NOT SPECIFIED
# software.amazon.awssdk:s3:VERSION NOT SPECIFIED
# software.amazon.kinesis:amazon-kinesis-client:2.3.9
# de.huxhorn.sulky:de.huxhorn.sulky.ulid:8.3.0
# com.algolia:algoliasearch-apache:3.16.1
# org.jasypt:jasypt:1.9.3
# eu.bitwalker:UserAgentUtils:1.21
# org.thymeleaf:thymeleaf-spring5:VERSION NOT SPECIFIED
# com.squareup.okhttp3:okhttp:4.9.3
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:logging:VERSION NOT SPECIFIED
# com.article.platform:grpc-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:secrets:VERSION NOT SPECIFIED
# com.article.platform:sdk-event:VERSION NOT SPECIFIED
# com.article.platform:archunit-tests-junit5:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/santa/src/79e52549ff7cb07e457c66d49325c06a76d84852/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# com.google.protobuf:protobuf-java:3.21.7
# com.article:protobuf:1.16.104
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.data:spring-data-redis:VERSION NOT SPECIFIED
# io.lettuce:lettuce-core:VERSION NOT SPECIFIED
# com.squareup.wire:wire-profiles:4.3.0
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatch:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.awssdk:sso:VERSION NOT SPECIFIED
# commons-validator:commons-validator:1.7
# com.squareup.okhttp3:okhttp:4.9.3
# commons-codec:commons-codec:VERSION PROPERTY NOT FOUND
# software.amazon.kinesis:amazon-kinesis-client:2.4.1
# com.google.guava:guava:31.0.1-jre
# org.apache.commons:commons-lang3:VERSION PROPERTY NOT FOUND
# com.article.platform:sdk-event:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# de.huxhorn.sulky:de.huxhorn.sulky.ulid:8.3.0
# com.fasterxml.jackson.datatype:jackson-datatype-jsr310:VERSION NOT SPECIFIED
# com.google.protobuf:protobuf-java-util:3.21.7
# io.confluent:kafka-avro-serializer:7.2.1
# com.article.platform:logging:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:grpc-spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.data:spring-data-redis:VERSION NOT SPECIFIED
# io.lettuce:lettuce-core:VERSION NOT SPECIFIED
# it.ozimov:embedded-redis:0.7.3
# it.ozimov:embedded-redis:0.7.3
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/blacksheepwall/src/b86946c41d967e89480e144887c288e9bda7ea73/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# com.article.platform:grpc-spring-boot-starter:VERSION NOT SPECIFIED
# com.article:protobuf:1.16.104
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# com.article.platform:logging:VERSION NOT SPECIFIED
# com.article.platform:sdk-event-producer:VERSION NOT SPECIFIED
# com.article.platform:sdk-event-consumer:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# com.maxmind.geoip2:geoip2:3.0.2
# io.confluent:kafka-avro-serializer:7.2.1
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatch:VERSION NOT SPECIFIED
# software.amazon.awssdk:sso:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-grpc/src/02ecd8861b8ef026f9d1e467b0a44fccd2a6393f/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.45
# org.springframework.boot:spring-boot-starter-freemarker:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-webflux:VERSION NOT SPECIFIED
# io.github.classgraph:classgraph:4.8.157
# org.projectlombok:lombok:1.18.26
# com.article:protobuf:1.16.104
# com.article.platform:sdk-common:1.4.45
# com.article.platform:secrets:1.4.45
# com.auth0:java-jwt:4.4.0
# com.auth0:jwks-rsa:0.22.0
# com.squareup.okhttp3:okhttp:4.9.3
# com.google.guava:guava:32.1.2-jre
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-cache-manager/src/94fb37f6fc66ca2b79cf08eafaa3cb0fc539791a/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.13.76
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-aop:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-rest:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-security:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-validation:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-log4j2:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-actuator:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-webflux:VERSION NOT SPECIFIED
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:5.7.3
# io.sentry:sentry-log4j2:5.7.3
# org.slf4j:slf4j-api:1.7.36
# org.apache.logging.log4j:log4j-api:2.17.2
# org.apache.logging.log4j:log4j-core:2.17.2
# org.apache.logging.log4j:log4j-slf4j-impl:2.17.2
# org.apache.logging.log4j:log4j-jcl:2.17.2
# org.apache.commons:commons-lang3:VERSION NOT SPECIFIED
# org.apache.httpcomponents:httpclient:VERSION NOT SPECIFIED
# org.atteo.classindex:classindex:3.11
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.springframework.security:spring-security-test:VERSION NOT SPECIFIED
# com.flipkart.zjsonpatch:zjsonpatch:0.4.12
# io.swagger:swagger-core:1.6.6
# com.fasterxml.jackson.core:jackson-databind:2.13.2.2
# com.article:identity-cli:0.3
# org.apache.avro:avro:1.8.1
# io.confluent:kafka-avro-serializer:5.2.2
# org.springframework.kafka:spring-kafka-test:VERSION NOT SPECIFIED
# junit:junit:4.13.2
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.awssdk:sts:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatch:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchevents:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchlogs:VERSION NOT SPECIFIED
# software.amazon.awssdk:s3:VERSION NOT SPECIFIED
# commons-io:commons-io:2.11.0
# com.google.code.gson:gson:2.8.9
# io.micrometer:micrometer-core:VERSION NOT SPECIFIED
# io.micrometer:micrometer-registry-cloudwatch2:1.8.5
# org.springdoc:springdoc-openapi-ui:1.6.7
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# org.ow2.asm:asm:6.2
# org.apache.maven.surefire:surefire-junit47:3.0.0-M6
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/mock-data-injector/src/e2c3eacc30e9ae7e337e8ffaadc66b03d083abe4/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.2.7
# org.apache.kafka:kafka-clients:7.2.1-ccs
# com.article.platform:bom:1.2.7
# com.article:protobuf:1.15.81
# io.confluent:kafka-protobuf-serializer:7.2.1
# com.fasterxml.jackson.core:jackson-core:2.14.0
# org.projectlombok:lombok:1.18.24
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/odysseus/src/b61aa36cdadcd90924dfdaee9ce2168055800a5d/pom.xml
# --------------------------------------------------------------------------------------------
# org.springframework.boot:spring-boot-starter-thymeleaf:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-web:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-devtools:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.springframework.plugin:spring-plugin-core:2.0.0.RELEASE
# org.hibernate.javax.persistence:hibernate-jpa-2.1-api:1.0.0.Final
# org.springframework.data:spring-data-commons:2.3.2.RELEASE
# com.article:identity-cli:1.0
# com.atlassian.jira:jira-rest-java-client-core:5.2.2
# com.atlassian.jira:jira-rest-java-client-api:5.2.0
# com.atlassian.jira:jira-rest-java-client-app:5.2.0
# com.atlassian.fugue:fugue:2.6.1
# joda-time:joda-time:2.10.5
# org.hibernate:hibernate-validator:5.4.1.Final
# org.apache.commons:commons-text:1.8
# org.awaitility:awaitility:3.1.2
# com.vdurmont:emoji-java:4.0.0
# org.springframework.security.oauth.boot:spring-security-oauth2-autoconfigure: ${project.parent.version}
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/arch.common/src/56ee79731c53c7660f86e7f94c9440c7e3c7c600/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awscdk:aws-cdk-lib:2.81.0
# software.constructs:constructs:[10.0.0,11.0.0)
# org.projectlombok:lombok:1.18.24
# org.junit.jupiter:junit-jupiter:5.7.1
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-service/src/7ff0ff63b7912efc46de0dca79dbc72e350f2eab/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.13.76
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-aop:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-rest:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-security:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-validation:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-log4j2:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-actuator:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-webflux:VERSION NOT SPECIFIED
# org.springframework.kafka:spring-kafka:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:3.2.0
# io.sentry:sentry-log4j2:3.2.0
# org.slf4j:slf4j-api:1.7.26
# org.apache.logging.log4j:log4j-api:2.17.0
# org.apache.logging.log4j:log4j-core:2.17.0
# org.apache.logging.log4j:log4j-slf4j-impl:2.17.0
# org.apache.logging.log4j:log4j-jcl:2.17.0
# org.apache.commons:commons-lang3:3.8.1
# org.apache.httpcomponents:httpclient:4.5.9
# org.atteo.classindex:classindex:3.6
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.springframework.security:spring-security-test:VERSION NOT SPECIFIED
# com.flipkart.zjsonpatch:zjsonpatch:0.4.8
# io.swagger:swagger-core:1.5.22
# org.hibernate:hibernate-core:5.4.28.Final
# org.hibernate:hibernate-ehcache:5.4.28.Final
# com.fasterxml.jackson.core:jackson-databind:2.11.4
# com.opencsv:opencsv:4.5
# com.article:identity-cli:1.4
# org.apache.avro:avro:1.8.2
# io.confluent:kafka-avro-serializer:5.2.2
# org.springframework.kafka:spring-kafka-test:VERSION NOT SPECIFIED
# junit:junit:4.13.2
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# org.flywaydb:flyway-core:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb:VERSION NOT SPECIFIED
# software.amazon.awssdk:dynamodb-enhanced:VERSION NOT SPECIFIED
# software.amazon.awssdk:sts:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatch:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchevents:VERSION NOT SPECIFIED
# software.amazon.awssdk:cloudwatchlogs:VERSION NOT SPECIFIED
# software.amazon.awssdk:s3:VERSION NOT SPECIFIED
# commons-io:commons-io:2.8.0
# com.google.code.gson:gson:2.8.5
# io.micrometer:micrometer-core:VERSION NOT SPECIFIED
# io.micrometer:micrometer-registry-cloudwatch2:1.5.11
# org.springdoc:springdoc-openapi-ui:1.5.9
# com.tngtech.archunit:archunit-junit4:0.23.1
# org.ow2.asm:asm:6.2
# org.apache.maven.surefire:surefire-junit47:3.0.0-M6
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-chatbot/src/0ab026b701017d3cc350f8f33d6cd7a60c442127/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.17.46
# com.article:identity-cli:1.4
# com.harium.suneidesis.sunbot:slack:1.6.7
# org.apache.httpcomponents:httpclient:4.5.13
# com.harium:dotenv:1.0.5
# com.fasterxml.jackson.core:jackson-databind:2.10.3
# org.jsoup:jsoup:1.13.1
# junit:junit:4.12
# org.mockito:mockito-all:1.10.19
# software.amazon.awssdk:secretsmanager:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/abacus/src/f1bb9778506071abf2ea34eb0a858508af1d3cf5/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# com.google.protobuf:protobuf-java:3.21.7
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# com.article:protobuf:1.16.104
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# com.google.protobuf:protobuf-java-util:3.21.7
# com.google.guava:guava:31.0.1-jre
# com.squareup.okhttp3:okhttp:4.9.3
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.optaplanner:optaplanner-core:7.34.0.Final
# com.fasterxml.jackson.datatype:jackson-datatype-jsr310:2.13.1
# io.lettuce:lettuce-core:6.2.1.RELEASE
# com.article.platform:logging:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:grpc-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:sdk-event-consumer:VERSION NOT SPECIFIED
# io.github.resilience4j:resilience4j-spring-boot2:1.7.1
# org.springframework.boot:spring-boot-starter-aop:2.7.1
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/treasury/src/04522386ac3a02d84cc297a4537517e9e0984c34/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.44
# com.google.protobuf:protobuf-java:3.21.7
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# mysql:mysql-connector-java:VERSION NOT SPECIFIED
# javax.xml.bind:jaxb-api:2.3.1
# org.springframework.data:spring-data-redis:VERSION NOT SPECIFIED
# io.lettuce:lettuce-core:VERSION NOT SPECIFIED
# com.article.platform:logging:VERSION NOT SPECIFIED
# com.article.platform:sdk-event-consumer:VERSION NOT SPECIFIED
# com.article:protobuf:1.16.104
# org.projectlombok:lombok:VERSION NOT SPECIFIED
# net.avalara.avatax:avatax-rest-v2-api-java_2.11:19.7.0
# com.taxjar:taxjar-java:5.0.1
# org.apache.commons:commons-collections4:4.4
# com.fasterxml.jackson.core:jackson-databind:2.13.4.2
# io.github.resilience4j:resilience4j-spring-boot2:1.7.1
# org.springframework.boot:spring-boot-starter-aop:2.7.1
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# org.apache.commons:commons-text:1.9
# io.sentry:sentry-logback:VERSION NOT SPECIFIED
# io.sentry:sentry-spring-boot-starter:VERSION NOT SPECIFIED
# com.stripe:stripe-java:20.96.0
# jakarta.xml.bind:jakarta.xml.bind-api:4.0.0-RC3
# io.confluent:kafka-avro-serializer:7.2.1
# com.paypal.sdk:rest-api-sdk:1.9.3
# com.github.tomakehurst:wiremock-jre8:2.33.2
# com.article.platform:grpc-spring-boot-starter:VERSION NOT SPECIFIED
# com.article.platform:secrets:VERSION NOT SPECIFIED
# it.ozimov:embedded-redis:0.7.3
# org.testcontainers:junit-jupiter:1.19.0
# org.testcontainers:testcontainers:1.19.0
# org.testcontainers:mysql:1.19.0
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-graph/src/4343c91e14d18e399894e2121c5c31472484cae5/pom.xml
# --------------------------------------------------------------------------------------------
# com.article.platform:bom:1.4.45
# org.springframework.boot:spring-boot-starter-graphql:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-webflux:VERSION NOT SPECIFIED
# com.article.platform:sdk-event-consumer:VERSION NOT SPECIFIED
# com.article.platform:sdk-service:VERSION NOT SPECIFIED
# com.article.platform:secrets:VERSION NOT SPECIFIED
# com.article:protobuf:1.16.104
# com.auth0:java-jwt:4.4.0
# com.auth0:jwks-rsa:0.22.0
# com.squareup.okhttp3:okhttp:VERSION NOT SPECIFIED
# org.mapstruct:mapstruct:1.5.5.Final
# org.projectlombok:lombok:1.18.24
# org.springframework.boot:spring-boot-starter-test:VERSION NOT SPECIFIED
# io.projectreactor:reactor-test:VERSION NOT SPECIFIED
# org.springframework.graphql:spring-graphql-test:VERSION NOT SPECIFIED
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/java-cdk-playground/src/71a2153120fa8a073dc4a30b53e1f9e7240eb067/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awscdk:aws-cdk-lib:2.21.1
# software.constructs:constructs:[10.0.0,11.0.0)
# org.junit.jupiter:junit-jupiter:5.7.1
# org.json:json:20180130
# org.projectlombok:lombok:1.18.22
# com.fasterxml.jackson.dataformat:jackson-dataformat-yaml:2.13.2
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/diagram-generator/src/a17a02056e61826f78e8201865371355651ebc28/pom.xml
# --------------------------------------------------------------------------------------------
# com.github.javaparser:javaparser-core-serialization:3.17.0
# com.fasterxml.jackson.core:jackson-databind:2.11.3
#
# --------------------------------------------------------------------------------------------
# File Name = pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-boxy/src/cdd4722f077311fb8370f58185878d296c53b917/pom.xml
# --------------------------------------------------------------------------------------------
# software.amazon.awssdk:bom:2.13.76
# com.article.platform:bom:1.0.26
# org.springframework.boot:spring-boot-starter:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-jpa:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-aop:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-data-rest:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-security:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-validation:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-log4j2:VERSION NOT SPECIFIED
# org.springframework.boot:spring-boot-starter-actuator:VERSION NOT SPECIFIED
# ...
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/cdk.json
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/grpc-gateway/src/b97118515fbbfa2b79f4ef78a2bb724f2b4de73b/cdk/cdk.json
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = backend/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/hackathon-megacast-2021/src/89ef02c7ad68f7f9976628886e73b1b58e36f06c/backend/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/deprecated-kraken-supply/src/4813a619b8ce734c163e93f70ac1c1e9559017f1/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk.json
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/ecomm-common-cdk/src/b9027883c1dee5d42b334f0eeaff278a2043302f/cdk.json
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = service/build/cdk/cdk.json
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/boxtosku/src/aa65855cf55e3dee7f3328e14a2a3577dc1c11e3/service/build/cdk/cdk.json
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/cdk.json
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/deep-thought/src/8812c5156ad4452a9f735f28caff802a78195061/cdk/cdk.json
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-dog/src/9ded1cc0a7971656c0eb4a4e067091d7e71832fc/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/article-cdk-lib/src/2611143b3ea040409e59f2314d8cb00c36de6611/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/cdk.json
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/perimeter/src/17a00d1af1ab3774660c1d2bfad42f97a1807943/cdk/cdk.json
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/cdk.json
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/contentful-publisher/src/d5a451ff141f76eeba4432abea3330534ec4940a/cdk/cdk.json
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-desk/src/e84b59d834851c4eb57e7959a432436138b741c1/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/liaison/src/b3539c788c703a80966990a3a58cd889b4ca6725/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = docs/hello-cdk/cdk-watch.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/cdk-workshop-docs/src/e66ee2800ee2ecd07fb5642957937e009238e1eb/docs/hello-cdk/cdk-watch.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = java-kafka-consumer-matrix/src/KafkaConsumerMatrixFunction/dependency-reduced-pom.xml
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/arch-lambdas/src/e482f058d17fee9f73407a888b10124e032c8b58/java-kafka-consumer-matrix/src/KafkaConsumerMatrixFunction/dependency-reduced-pom.xml
# --------------------------------------------------------------------------------------------
# junit:junit:4.13.1
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-seshat/src/149e81d56b8039d772c2e6e0692f196532a9c871/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-tracker/src/408771b0eb3af86c0bcfeff4acca21ea94d80f86/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = bootstrap.sh
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/mohsen-test/src/f9bec7c11971eda78074de1109f8004d39efcdee/bootstrap.sh
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = docs/my-first-cdk-project/project-structure.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/cdk-workshop-docs/src/e66ee2800ee2ecd07fb5642957937e009238e1eb/docs/my-first-cdk-project/project-structure.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-boxy/src/cdd4722f077311fb8370f58185878d296c53b917/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/protobuf/src/cd526c4748db457aeaa0debdf57e332123e85ccb/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-product/src/527acdda2ab4f9296f16547571973e0203052fa0/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/alchemist/src/7ac2dc38ded8639ccd86cacb222e995fb7ba85fc/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/ecomm-common-cdk/src/b9027883c1dee5d42b334f0eeaff278a2043302f/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/backbone.common/src/1f6f1e969833aefc193eebcfdcf787e0b98602d1/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/contentful-publisher/src/d5a451ff141f76eeba4432abea3330534ec4940a/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/deep-thought/src/8812c5156ad4452a9f735f28caff802a78195061/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/curator/src/d00d2d12c27907629ec710bf5cd3f9049bb245ac/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/chronicler/src/cb5364075237557170c97415e8a06abc4de1593c/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/article-in-a-box-hackathon/src/0d6d2741abd44283b68a5ceea66048ef970fc8c5/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/grpc-gateway/src/b97118515fbbfa2b79f4ef78a2bb724f2b4de73b/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/santa/src/79e52549ff7cb07e457c66d49325c06a76d84852/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/perimeter/src/17a00d1af1ab3774660c1d2bfad42f97a1807943/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = infrastructure/cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/article/src/c46ce8422601f7dbd13b0937b2e30b3237dcfd2f/infrastructure/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/blacksheepwall/src/b86946c41d967e89480e144887c288e9bda7ea73/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/pulsar/src/8121f33a33ba77295c91e721df4a07bd29282f11/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = cdk/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/doorcrasher/src/e810588e51913fabd1c4b90654ff880f969f3ae6/cdk/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = java-kafka-consumer-matrix/README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/arch-lambdas/src/e482f058d17fee9f73407a888b10124e032c8b58/java-kafka-consumer-matrix/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-data-pump/src/6fb492605b0f26c96c4fbdb0f98e11ce6ea27352/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-claim/src/066413ae96719e4d6ee1b6cb748a6de308922f76/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/arch.common/src/56ee79731c53c7660f86e7f94c9440c7e3c7c600/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-log/src/fd17e9b79d758f3d7eed0f51d1bf88285c4cd290/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-schedule/src/acaff6a00cc383c27517f58d59db41d9061dbc01/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = README.md
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/kraken-setting/src/b6f16acc4227f4cc55fc7e913ac3cd53e134d623/README.md
# --------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------
# File Name = jira-creation/package/botocore/data/codeartifact/2018-09-22/service-2.json
# File Path = https://api.bitbucket.org/2.0/repositories/articledev/aws-lambda/src/0a9c12cb19b7173b8fd16e66054c9d4d229e171e/jira-creation/package/botocore/data/codeartifact/2018-09-22/service-2.json
# --------------------------------------------------------------------------------------------
